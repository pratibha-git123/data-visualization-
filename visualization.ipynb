# %%
import pandas as pd

# %%
df = pd.read_csv('foot.csv')
df
# Out:
#                                                   name  \
# 0    Women's Casual Sports Shoes, Fashionable Versa...
# 1    2024 New Spring/Autumn Women Breathable Mesh H...
# 2    Women's Casual Slip-on Flat Skate Shoes With A...
# 3    Women Mesh Breathable Casual Shoes, Soft Non-S...
# 4                  Women's Fashionable Casual Sneakers
# ..                                                 ...
# 894  Women's Spring And Autumn Fashionable Square F...
# 895  Women's Fashionable Casual Sports Color Block ...
# 896  1pair Super Soft Shoes Front Insole Sponge Hal...
# 897  Summer Men's Hiking Aqua Shoes With Thick Sole...
# 898  2pcs Letter Graphic Shoe Insoles, Fashion Apri...
#
#                                                   link  price_usd  \
# 0    https://us.shein.com/Women-s-Casual-Sports-Sho...      19.40
# 1    https://us.shein.com/2024-New-Spring-Autumn-Wo...      14.90
# 2    https://us.shein.com/Women-s-Casual-Slip-on-Fl...       7.50
# ...

# %%
df.describe()
# Out:
#         price_usd  mark_price_usd  star_rating
# count  899.000000      899.000000   899.000000
# mean    17.303537       23.231624     0.043437
# std     15.234275       18.266408     0.458675
# min      0.610000        2.100000     0.000000
# 25%     11.900000       16.200000     0.000000
# 50%     15.800000       21.000000     0.000000
# 75%     19.990000       26.000000     0.000000
# max    247.500000      319.070000     4.920000

# %%
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt

# %%
x= ['Pratibha','Yamini','Riddhi','Siya']
y= [88,57,78,77]
plt.plot(x,y)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    12 non-null     object
#  1   Marks   11 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 320.0+ bytes

# %%
df = pd.read_csv('practice.csv')
df
# Out:
#    Name  Marks
# 0     a     45
# 1     b     45
# 2     c     60
# 3     d     66
# 4     e     71
# 5     f     81
# 6     g     77
# 7     h     56
# 8     i     73
# 9     j     66
# 10    k     65
# 11    l     45

# %%
x = df['Name']
y = df['Marks']
plt.plot(x,y, marker='*', color='y', lw=2)#LW Afor line width
#plt.plot(x,y, marker='D')
#plt.plot(x,y, marker='o')
#plt.plot(x,y, '<:r')
#plt.plot(x,y, marker='D')

# %%
plt.plot(x,y, '*r' , ms=18)# ms for marker size

# %%
df.head()
# Out:
#   Name  Marks
# 0    a     45
# 1    b     45
# 2    c     60
# 3    d     66
# 4    e     71

# %%
plt.plot(x,y, '*-b' )
plt.title('ADIT - Class',{'color':'red', 'family':'serif'})
plt.grid( linestyle='-.',color='g')
#plt.grid(axis='y')for only y

# %%
plt.plot(x,y, 'o-.g' )
plt.title('ADIT - Class',{'color':'b', 'family':'serif'})
plt.grid( linestyle='-.',color='r', mouseover=True)

# %%
plt.figure()
plt.title('ADIT - Class',{'color':'red', 'family':'serif'})
plt.grid( linestyle='-.',color='r')
plt.bar(x,y, color='blue')
# Out:
# <BarContainer object of 12 artists>

# %%
x= [40,35,42,25]
plt.pie(x, labels=['Pratibha','Raju','Ram','Zoya'])
# Out:
# ([<matplotlib.patches.Wedge at 0x27632a39030>,
# ...
#  [Text(0.6966561575338371, 0.851275629963756, 'Pratibha'),
#   Text(-0.9095149944934202, 0.6186941690299287, 'Raju'),
#   Text(-0.49287344812157363, -0.9834001037913057, 'Ram'),
#   Text(0.9359916647421946, -0.577857771024268, 'Zoya')])

# %%
x= [40,35,42,25]
plt.pie(x, labels=['Pratibha','Raju','Ram','Zoya'], 
        colors=['cyan','green','yellow','pink'],
       counterclock=False,
       )
# Out:
# ([<matplotlib.patches.Wedge at 0x27632a8c490>,
# ...
#  [Text(0.6966561575338371, -0.851275629963756, 'Pratibha'),
#   Text(-0.9095149944934202, -0.6186941690299287, 'Raju'),
#   Text(-0.49287344812157363, 0.9834001037913057, 'Ram'),
#   Text(0.9359916647421946, 0.577857771024268, 'Zoya')])

# %%
x= [40,35,42,25]
plt.pie(x, labels=['Pratibha','Raju','Ram','Zoya'], explode=[1,0,0,0])
# Out:
# ([<matplotlib.patches.Wedge at 0x27624ea1990>,
# ...
#  [Text(1.3299799371100527, 1.6251625662944433, 'Pratibha'),
#   Text(-0.9095149944934202, 0.6186941690299287, 'Raju'),
#   Text(-0.49287344812157363, -0.9834001037913057, 'Ram'),
#   Text(0.9359916647421946, -0.577857771024268, 'Zoya')])

# %%
data=pd.read_csv('scatter.csv')
data
# Out:
#      x     y
# 0   39  30.0
# 1   85  86.0
# 2   69   5.0
# 3   44  97.0
# 4   75  80.0
# 5   77  22.0
# 6    7  54.0
# 7   57  41.0
# 8   98  27.0
# 9   60  83.0
# 10  76  74.0
# 11  72  52.0
# 12   8   6.0
# 13  87   6.0
# 14  59   1.0
# 15  24  42.0
# 16  14  66.0
# 17  48  69.0
# 18  80  46.0
# 19  90  75.0
# 20  95  39.0
# 21  37  63.0
# 22  91  46.0
# 23  32  85.0
# 24  43  34.0
# 25  24  87.0
# 26  24  89.0
# 27  27  70.0
# 28  65   NaN

# %%
x=data['x']
y=data['y']
plt.scatter(x,y)

# %%
plt.scatter(x,y, color='green', marker='^')

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x27632926230>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x27632eb3850>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x27632926170>],
#  'medians': [<matplotlib.lines.Line2D at 0x27632daa3e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x27632da9ae0>],
#  'means': []}

# %%
data.describe()
# Out:
#                x          y
# count  29.000000  28.000000
# mean   55.413793  52.678571
# std    27.872820  28.790499
# min     7.000000   1.000000
# 25%    32.000000  33.000000
# 50%    59.000000  53.000000
# 75%    77.000000  76.250000
# max    98.000000  97.000000
